# %%
import pandas as pd
x1 = pd.read_csv('x1.csv')
y1 = pd.read_csv('y1.csv')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

x1.head()
# Out:
#    Unnamed: 0         0         1         2         3         4         5  \
# 0           0 -1.710534 -0.171345 -0.897650  0.793217  0.483610  0.793563
# 1           1 -1.667229 -0.329434 -0.898398  0.889544  0.385783  0.581812
# 2           2 -1.623924 -0.473434 -0.886577  1.010810  0.248905  0.306659
# 3           3 -1.580620 -0.596645 -0.869564  1.114297  0.069716  0.001750
# 4           4 -1.537315 -0.674571 -0.853696  1.164825 -0.150855 -0.303005
#
#           6         7         8  ...        39        40        41        42  \
# 0 -0.545002  0.047152 -0.682902  ...  0.500196  4.387459 -0.210565  0.887804
# 1 -0.559549 -0.132307 -0.785795  ...  0.504513  4.314970 -0.014712  0.831384
# 2 -0.618386 -0.312167 -0.890220  ...  0.568015  4.105673  0.043620  0.783981
# 3 -0.717880 -0.459852 -0.974513  ...  0.619410  3.830838  0.005705  0.748073
# 4 -0.847528 -0.548517 -1.019592  ...  0.599541  3.539310 -0.060991  0.719321
#
# ...

# %%
plt.plot(x1.values[:,2],'r')
plt.plot(y1.values[:,2],'g')
