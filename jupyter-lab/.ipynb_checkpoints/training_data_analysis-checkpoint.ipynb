# %%
import os
import sys
sys.path.append("./../")
import numpy as np
import matplotlib.pyplot as plt
import pdb
import pandas as pd
import yaml
import h5py
import vicon_imu_data_process.process_landing_data as pro_rd
import estimation_assessment.scores as es_as

import seaborn as sns
import copy
import re
import json

from vicon_imu_data_process.const import FEATURES_FIELDS, LABELS_FIELDS, DATA_PATH
from vicon_imu_data_process.const import DROPLANDING_PERIOD, RESULTS_PATH
from vicon_imu_data_process import const
from vicon_imu_data_process.dataset import *

from estimation_models.rnn_models import *
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import LeaveOneOut
from sklearn.model_selection import KFold
import time as localtimepkg

from estimation_study import *
from estimation_assessment.visualization import *
#import pdb
import re
# Out:
# tensorflow version: 2.5.0
# tensorflow version: 2.5.0
# [LogicalDevice(name='/device:CPU:0', device_type='CPU')] []

# %%
subjects_trials_dataset = pro_rd.load_subjects_dataset(h5_file_name = os.path.join(DATA_PATH,'kam_norm_landing_data.hdf5'))

# %%
subjects_trials_dataset.keys()
subjects_trials_dataset['P_08_zhangboyuan']['01']
# Out:
#         TIME  CHEST_Accel_X  CHEST_Accel_Y  CHEST_Accel_Z  CHEST_Gyro_X  \
# 0  -1.710534      -0.307743      -0.848483       0.886402      0.201739
# 1  -1.667229      -0.280371      -0.802816       0.910427      0.093627
# 2  -1.623924      -0.244814      -0.774021       0.932067     -0.034777
# 3  -1.580620      -0.198346      -0.760491       0.951081     -0.182230
# 4  -1.537315      -0.135312      -0.757351       0.966908     -0.341787
# ..       ...            ...            ...            ...           ...
# 75  1.537315       0.257972      -0.011182       1.133225     -0.240339
# 76  1.580620       0.193218      -0.036154       1.121625     -0.263476
# 77  1.623924       0.127517      -0.056372       1.109515     -0.268156
# 78  1.667229       0.067892      -0.071170       1.097860     -0.254249
# 79  1.710534       0.022020      -0.081206       1.088522     -0.222367
#
#     CHEST_Gyro_Y  CHEST_Gyro_Z  WAIST_Accel_X  WAIST_Accel_Y  WAIST_Accel_Z  \
# 0       0.832931      0.105811      -0.409672      -0.812233       1.219347
# 1       0.909836      0.041653      -0.465538      -0.866906       1.214529
# 2       1.001446     -0.023239      -0.396340      -0.895519       1.198755
# 3       1.079027     -0.081435      -0.227489      -0.894633       1.179919
# 4       1.115470     -0.128699      -0.006415      -0.867088       1.165251
# ..           ...           ...            ...            ...            ...
# 75      0.062359      0.207354       0.574025      -0.042988       0.564440
# 76      0.030059      0.221108       0.580499      -0.065291       0.558010
# 77      0.006586      0.222826       0.571514      -0.079616       0.539181
# 78     -0.007835      0.216033       0.549768      -0.084547       0.509169
# 79     -0.015940      0.204543       0.524404      -0.080168       0.474075
#
#     ...  L_SHANK_Gyro_X  L_SHANK_Gyro_Y  L_SHANK_Gyro_Z  L_FOOT_Accel_X  \
# 0   ...       -0.341793        2.015743        1.318920        0.007890
# 1   ...       -0.331984        1.773624        1.277570       -0.293376
# 2   ...       -0.312840        1.428282        1.243045       -0.618836
# 3   ...       -0.284975        1.038673        1.210406       -0.950486
# 4   ...       -0.247801        0.664248        1.170919       -1.246950
# ..  ...             ...             ...             ...             ...
# 75  ...        0.047016       -0.121612       -0.045492        0.296214
# 76  ...        0.058480       -0.077985       -0.053130        0.301120
# 77  ...        0.066940       -0.036555       -0.063215        0.313075
# 78  ...        0.069797       -0.013909       -0.073312        0.328938
# 79  ...        0.065992       -0.015007       -0.082575        0.343047
#
#     L_FOOT_Accel_Y  L_FOOT_Accel_Z  L_FOOT_Gyro_X  L_FOOT_Gyro_Y  \
# 0         0.214291       -0.785808       0.429048       0.295970
# 1         0.304545       -0.716163       0.365726       0.239581
# 2         0.289109       -0.761043       0.267304       0.078228
# 3         0.218353       -0.899204       0.184937      -0.161500
# 4         0.150590       -1.085972       0.147702      -0.440947
# ..             ...             ...            ...            ...
# 75       -0.262877        0.444766       0.206899      -0.125350
# 76       -0.265009        0.442733       0.199733      -0.131683
# 77       -0.269360        0.440253       0.193788      -0.134216
# 78       -0.275995        0.437672       0.189357      -0.131502
# 79       -0.284655        0.435335       0.186502      -0.123500
#
#     L_FOOT_Gyro_Z  R_KNEE_MOMENT_X
# 0        2.494976        -0.681864
# 1        2.377982        -0.680241
# 2        2.204453        -0.679721
# 3        1.963400        -0.682034
# 4        1.657702        -0.685047
# ..            ...              ...
# 75      -0.158966        -0.343186
# 76      -0.150144        -0.353327
# 77      -0.142295        -0.360142
# 78      -0.137383        -0.366597
# 79      -0.136349        -0.376936
#
# [80 rows x 50 columns]

# %%
np.linspace(-5,5, 121)
# Out:
# array([-5.        , -4.91666667, -4.83333333, -4.75      , -4.66666667,
#        -4.58333333, -4.5       , -4.41666667, -4.33333333, -4.25      ,
#        -4.16666667, -4.08333333, -4.        , -3.91666667, -3.83333333,
#        -3.75      , -3.66666667, -3.58333333, -3.5       , -3.41666667,
#        -3.33333333, -3.25      , -3.16666667, -3.08333333, -3.        ,
#        -2.91666667, -2.83333333, -2.75      , -2.66666667, -2.58333333,
#        -2.5       , -2.41666667, -2.33333333, -2.25      , -2.16666667,
#        -2.08333333, -2.        , -1.91666667, -1.83333333, -1.75      ,
#        -1.66666667, -1.58333333, -1.5       , -1.41666667, -1.33333333,
#        -1.25      , -1.16666667, -1.08333333, -1.        , -0.91666667,
#        -0.83333333, -0.75      , -0.66666667, -0.58333333, -0.5       ,
#        -0.41666667, -0.33333333, -0.25      , -0.16666667, -0.08333333,
#         0.        ,  0.08333333,  0.16666667,  0.25      ,  0.33333333,
#         0.41666667,  0.5       ,  0.58333333,  0.66666667,  0.75      ,
#         0.83333333,  0.91666667,  1.        ,  1.08333333,  1.16666667,
#         1.25      ,  1.33333333,  1.41666667,  1.5       ,  1.58333333,
#         1.66666667,  1.75      ,  1.83333333,  1.91666667,  2.        ,
#         2.08333333,  2.16666667,  2.25      ,  2.33333333,  2.41666667,
#         2.5       ,  2.58333333,  2.66666667,  2.75      ,  2.83333333,
#         2.91666667,  3.        ,  3.08333333,  3.16666667,  3.25      ,
#         3.33333333,  3.41666667,  3.5       ,  3.58333333,  3.66666667,
#         3.75      ,  3.83333333,  3.91666667,  4.        ,  4.08333333,
#         4.16666667,  4.25      ,  4.33333333,  4.41666667,  4.5       ,
#         4.58333333,  4.66666667,  4.75      ,  4.83333333,  4.91666667,
#         5.        ])

# %%
augment_subjects_trials_dataset = pro_rd.load_subjects_dataset(h5_file_name = os.path.join(DATA_PATH,'2_5d_augment_kam_norm_landing_data.hdf5'))
augment_subjects_trials_dataset.keys()
#print(subjects_trials_dataset['P_08_zhangboyuan'].keys())
augment_subjects_trials_dataset['P_08_zhangboyuan']['01_17']
# Out:
#         TIME  CHEST_Accel_X  CHEST_Accel_Y  CHEST_Accel_Z  CHEST_Gyro_X  \
# 0  -1.710534      -0.300230      -0.848422       0.886402      0.201797
# 1  -1.667229      -0.273527      -0.802739       0.910427      0.093652
# 2  -1.623924      -0.238839      -0.773934       0.932067     -0.034790
# 3  -1.580620      -0.193507      -0.760401       0.951081     -0.182287
# 4  -1.537315      -0.132013      -0.757259       0.966908     -0.341891
# ..       ...            ...            ...            ...           ...
# 75  1.537315       0.251660      -0.010846       1.133225     -0.240414
# 76  1.580620       0.188489      -0.035826       1.121625     -0.263557
# 77  1.623924       0.124394      -0.056051       1.109515     -0.268239
# 78  1.667229       0.066226      -0.070854       1.097860     -0.254328
# 79  1.710534       0.021475      -0.080894       1.088522     -0.222436
#
#     CHEST_Gyro_Y  CHEST_Gyro_Z  WAIST_Accel_X  WAIST_Accel_Y  WAIST_Accel_Z  \
# 0       0.830642      0.105811      -0.399932      -0.812212       1.219347
# 1       0.907336      0.041653      -0.454466      -0.866903       1.214529
# 2       0.998694     -0.023239      -0.386917      -0.895525       1.198755
# 3       1.076062     -0.081435      -0.222089      -0.894639       1.179919
# 4       1.112405     -0.128699      -0.006283      -0.867085       1.165251
# ..           ...           ...            ...            ...            ...
# 75      0.062186      0.207354       0.560326      -0.042715       0.564440
# 76      0.029975      0.221108       0.566646      -0.065025       0.558010
# 77      0.006567      0.222826       0.557875      -0.079355       0.539181
# 78     -0.007814      0.216033       0.536647      -0.084287       0.509169
# 79     -0.015897      0.204543       0.511887      -0.079906       0.474075
#
#     ...  L_SHANK_Gyro_X  L_SHANK_Gyro_Y  L_SHANK_Gyro_Z  L_FOOT_Accel_X  \
# 0   ...       -0.341726        2.015997        1.318920        0.007913
# 1   ...       -0.331919        1.773849        1.277570       -0.292849
# 2   ...       -0.312779        1.428468        1.243045       -0.617765
# 3   ...       -0.284918        1.038815        1.210406       -0.948860
# 4   ...       -0.247751        0.664347        1.170919       -1.244828
# ..  ...             ...             ...             ...             ...
# 75  ...        0.047015       -0.121602       -0.045492        0.295755
# 76  ...        0.058477       -0.077971       -0.053130        0.300652
# 77  ...        0.066936       -0.036536       -0.063215        0.312588
# 78  ...        0.069791       -0.013887       -0.073312        0.328424
# 79  ...        0.065987       -0.014985       -0.082575        0.342509
#
#     L_FOOT_Accel_Y  L_FOOT_Accel_Z  L_FOOT_Gyro_X  L_FOOT_Gyro_Y  \
# 0         0.214677       -0.785808       0.429073       0.295735
# 1         0.304951       -0.716163       0.365736       0.239395
# 2         0.289512       -0.761043       0.267291       0.078181
# 3         0.218740       -0.899204       0.184904      -0.161341
# 4         0.150963       -1.085972       0.147660      -0.440547
# ..             ...             ...            ...            ...
# 75       -0.262596        0.444766       0.206871      -0.125222
# 76       -0.264729        0.442733       0.199703      -0.131549
# 77       -0.269081        0.440253       0.193757      -0.134080
# 78       -0.275718        0.437672       0.189325      -0.131369
# 79       -0.284379        0.435335       0.186469      -0.123373
#
#     L_FOOT_Gyro_Z  R_KNEE_MOMENT_X
# 0        2.494976        -0.681864
# 1        2.377982        -0.680241
# 2        2.204453        -0.679721
# 3        1.963400        -0.682034
# 4        1.657702        -0.685047
# ..            ...              ...
# 75      -0.158966        -0.343186
# 76      -0.150144        -0.353327
# 77      -0.142295        -0.360142
# 78      -0.137383        -0.366597
# 79      -0.136349        -0.376936
#
# [80 rows x 50 columns]

# %%
v2_augment_subjects_trials_dataset = pro_rd.load_subjects_dataset(h5_file_name = os.path.join(DATA_PATH,'v2_2_5d_augment_kam_norm_landing_data.hdf5'))
#print(subjects_trials_dataset['P_08_zhangboyuan'].keys())
v2_augment_subjects_trials_dataset['P_08_zhangboyuan']['01_17']
# Out:
#     CHEST_Accel_X  CHEST_Accel_Y  CHEST_Accel_Z  CHEST_Gyro_X  CHEST_Gyro_Y  \
# 0       -0.307743      -0.848483       0.886402      0.201739      0.832931
# 1       -0.280371      -0.802816       0.910427      0.093627      0.909836
# 2       -0.244814      -0.774021       0.932067     -0.034777      1.001446
# 3       -0.198346      -0.760491       0.951081     -0.182230      1.079027
# 4       -0.135312      -0.757351       0.966908     -0.341787      1.115470
# ..            ...            ...            ...           ...           ...
# 75       0.257972      -0.011182       1.133225     -0.240339      0.062359
# 76       0.193218      -0.036154       1.121625     -0.263476      0.030059
# 77       0.127517      -0.056372       1.109515     -0.268156      0.006586
# 78       0.067892      -0.071170       1.097860     -0.254249     -0.007835
# 79       0.022020      -0.081206       1.088522     -0.222367     -0.015940
#
#     CHEST_Gyro_Z  WAIST_Accel_X  WAIST_Accel_Y  WAIST_Accel_Z  WAIST_Gyro_X  \
# 0       0.105811      -0.409672      -0.812233       1.219347     -0.198479
# 1       0.041653      -0.465538      -0.866906       1.214529     -0.323971
# 2      -0.023239      -0.396340      -0.895519       1.198755     -0.399684
# 3      -0.081435      -0.227489      -0.894633       1.179919     -0.439617
# 4      -0.128699      -0.006415      -0.867088       1.165251     -0.464982
# ..           ...            ...            ...            ...           ...
# 75      0.207354       0.574025      -0.042988       0.564440     -0.109085
# 76      0.221108       0.580499      -0.065291       0.558010     -0.068496
# 77      0.222826       0.571514      -0.079616       0.539181     -0.021621
# 78      0.216033       0.549768      -0.084547       0.509169      0.025668
# 79      0.204543       0.524404      -0.080168       0.474075      0.066631
#
#     ...  L_SHANK_Gyro_Y  L_SHANK_Gyro_Z  L_FOOT_Accel_X  L_FOOT_Accel_Y  \
# 0   ...        2.015743        1.318920        0.007890        0.214291
# 1   ...        1.773624        1.277570       -0.293376        0.304545
# 2   ...        1.428282        1.243045       -0.618836        0.289109
# 3   ...        1.038673        1.210406       -0.950486        0.218353
# 4   ...        0.664248        1.170919       -1.246950        0.150590
# ..  ...             ...             ...             ...             ...
# 75  ...       -0.121612       -0.045492        0.296214       -0.262877
# 76  ...       -0.077985       -0.053130        0.301120       -0.265009
# 77  ...       -0.036555       -0.063215        0.313075       -0.269360
# 78  ...       -0.013909       -0.073312        0.328938       -0.275995
# 79  ...       -0.015007       -0.082575        0.343047       -0.284655
#
#     L_FOOT_Accel_Z  L_FOOT_Gyro_X  L_FOOT_Gyro_Y  L_FOOT_Gyro_Z      TIME  \
# 0        -0.785808       0.429048       0.295970       2.494976 -1.710534
# 1        -0.716163       0.365726       0.239581       2.377982 -1.667229
# 2        -0.761043       0.267304       0.078228       2.204453 -1.623924
# 3        -0.899204       0.184937      -0.161500       1.963400 -1.580620
# 4        -1.085972       0.147702      -0.440947       1.657702 -1.537315
# ..             ...            ...            ...            ...       ...
# 75        0.444766       0.206899      -0.125350      -0.158966  1.537315
# 76        0.442733       0.199733      -0.131683      -0.150144  1.580620
# 77        0.440253       0.193788      -0.134216      -0.142295  1.623924
# 78        0.437672       0.189357      -0.131502      -0.137383  1.667229
# 79        0.435335       0.186502      -0.123500      -0.136349  1.710534
#
#     R_KNEE_MOMENT_X
# 0         -0.681864
# 1         -0.680241
# 2         -0.679721
# 3         -0.682034
# 4         -0.685047
# ..              ...
# 75        -0.343186
# 76        -0.353327
# 77        -0.360142
# 78        -0.366597
# 79        -0.376936
#
# [80 rows x 50 columns]

# %%
sub = list(v2_augment_subjects_trials_dataset.keys())

# %%
sub
# Out:
# ['P_10_dongxuan',
#  'P_11_liuchunyu',
#  'P_13_xulibang',
#  'P_14_hunan',
#  'P_15_liuzhaoyu',
#  'P_16_zhangjinduo',
#  'P_17_congyuanqi',
#  'P_18_hezhonghai',
#  'P_19_xiongyihui',
#  'P_20_xuanweicheng',
#  'P_21_wujianing',
#  'P_22_zhangning',
#  'P_23_wangjinhong',
#  'P_24_liziqing']
